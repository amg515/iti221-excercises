# %% [markdown]
# Module 5 Exercise
# Ansel Gomez
# Section 2

# %%
import pandas as pd

# %% [markdown]
# Load the following columns of csv file located here (Links to an external site.) into a Pandas dataframe (1 point)
#     play_id
#     game_id
#     home_team
#     away_team
#     game_date
#     play_type
#     replay_or_challenge
#     replay_or_challenge_result

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ryurko/nflscrapR-data/master/play_by_play_data/post_season/post_pbp_2009.csv", 
                 usecols=["play_id", "game_id", "home_team", "away_team", "game_date", "play_type", "replay_or_challenge", "replay_or_challenge_result"])
df
# Out:
#       play_id     game_id home_team away_team   game_date play_type  \
# 0          36  2010010901       CIN       NYJ  2010-01-09   kickoff
# 1          61  2010010901       CIN       NYJ  2010-01-09       run
# 2          82  2010010901       CIN       NYJ  2010-01-09      pass
# 3         104  2010010901       CIN       NYJ  2010-01-09      pass
# 4         166  2010010901       CIN       NYJ  2010-01-09       run
# ...       ...         ...       ...       ...         ...       ...
# 2097     3677  2010020700       IND        NO  2010-02-07      pass
# 2098     3700  2010020700       IND        NO  2010-02-07       run
# 2099     3721  2010020700       IND        NO  2010-02-07      pass
# 2100     3743  2010020700       IND        NO  2010-02-07  qb_kneel
# 2101     3768  2010020700       IND        NO  2010-02-07       NaN
#
#       replay_or_challenge replay_or_challenge_result
# 0                       0                        NaN
# ...

# %% [markdown]
# Count the number of missing entries in this dataframe. (1 point)

# %%
missing_entries = df.isna().sum().sum()

# %%
missing_entries
# Out:
# 2157

# %% [markdown]
# What percentage of entries in the dataframe are missing? (1 point)

# %%
total_entries = df.shape[1] * len(df)

# %%
(missing_entries / total_entries) * 100
# Out:
# 12.827069457659372

# %% [markdown]
# If you removed all the rows containing a missing value, how many rows would remain? (1 point)

# %%
rows_cleaned = df.dropna()

# %%
rows_cleaned.shape[0]
# Out:
# 15

# %% [markdown]
# If you removed all the columns containing a missing value, how many columns would remain? (1 point)

# %%
columns_cleaned = df.dropna(axis=1)

# %%
columns_cleaned.shape[1]
# Out:
# 6

# %% [markdown]
# Repeat Step 1, if your dataframe has changed. Replace all NaN values in the play_type column with ‘pass’. (1 point)

# %%
df['play_type'] =  df['play_type'].replace({np.nan:'pass'})
df
# Out:
#       play_id     game_id home_team away_team   game_date play_type  \
# 0          36  2010010901       CIN       NYJ  2010-01-09   kickoff
# 1          61  2010010901       CIN       NYJ  2010-01-09       run
# 2          82  2010010901       CIN       NYJ  2010-01-09      pass
# 3         104  2010010901       CIN       NYJ  2010-01-09      pass
# 4         166  2010010901       CIN       NYJ  2010-01-09       run
# ...       ...         ...       ...       ...         ...       ...
# 2097     3677  2010020700       IND        NO  2010-02-07      pass
# 2098     3700  2010020700       IND        NO  2010-02-07       run
# 2099     3721  2010020700       IND        NO  2010-02-07      pass
# 2100     3743  2010020700       IND        NO  2010-02-07  qb_kneel
# 2101     3768  2010020700       IND        NO  2010-02-07      pass
#
#       replay_or_challenge replay_or_challenge_result
# 0                       0                        NaN
# ...

# %% [markdown]
# Make all the values in play_type column UPPER CASE. (1 point)

# %%
df['play_type'] = df['play_type'].str.upper()
df
# Out:
#       play_id     game_id home_team away_team   game_date play_type  \
# 0          36  2010010901       CIN       NYJ  2010-01-09   KICKOFF
# 1          61  2010010901       CIN       NYJ  2010-01-09       RUN
# 2          82  2010010901       CIN       NYJ  2010-01-09      PASS
# 3         104  2010010901       CIN       NYJ  2010-01-09      PASS
# 4         166  2010010901       CIN       NYJ  2010-01-09       RUN
# ...       ...         ...       ...       ...         ...       ...
# 2097     3677  2010020700       IND        NO  2010-02-07      PASS
# 2098     3700  2010020700       IND        NO  2010-02-07       RUN
# 2099     3721  2010020700       IND        NO  2010-02-07      PASS
# 2100     3743  2010020700       IND        NO  2010-02-07  QB_KNEEL
# 2101     3768  2010020700       IND        NO  2010-02-07      PASS
#
#       replay_or_challenge replay_or_challenge_result
# 0                       0                        NaN
# ...

# %% [markdown]
# How many distinct play types exist in your data? (1 point)

# %%
unique_play =  df.drop_duplicates(['play_type'])
unique_play
# Out:
#      play_id     game_id home_team away_team   game_date    play_type  \
# 0         36  2010010901       CIN       NYJ  2010-01-09      KICKOFF
# 1         61  2010010901       CIN       NYJ  2010-01-09          RUN
# 2         82  2010010901       CIN       NYJ  2010-01-09         PASS
# 8        253  2010010901       CIN       NYJ  2010-01-09      NO_PLAY
# 10       300  2010010901       CIN       NYJ  2010-01-09         PUNT
# 18       531  2010010901       CIN       NYJ  2010-01-09  EXTRA_POINT
# 98      2405  2010010901       CIN       NYJ  2010-01-09   FIELD_GOAL
# 164     3918  2010010901       CIN       NYJ  2010-01-09     QB_KNEEL
# 795     2099  2010011601        NO       ARI  2010-01-16     QB_SPIKE
#
#      replay_or_challenge replay_or_challenge_result
# 0                      0                        NaN
# 1                      0                        NaN
# 2                      0                        NaN
# 8                      0                        NaN
# ...

# %%
len(unique_play)
# Out:
# 9

# %% [markdown]
# Make only the ‘home_team’ column name UPPER CASE. (1 point)

# %%
df['home_team'] = df['home_team'].str.upper()
df
# Out:
#       play_id     game_id home_team away_team   game_date play_type  \
# 0          36  2010010901       CIN       NYJ  2010-01-09   KICKOFF
# 1          61  2010010901       CIN       NYJ  2010-01-09       RUN
# 2          82  2010010901       CIN       NYJ  2010-01-09      PASS
# 3         104  2010010901       CIN       NYJ  2010-01-09      PASS
# 4         166  2010010901       CIN       NYJ  2010-01-09       RUN
# ...       ...         ...       ...       ...         ...       ...
# 2097     3677  2010020700       IND        NO  2010-02-07      PASS
# 2098     3700  2010020700       IND        NO  2010-02-07       RUN
# 2099     3721  2010020700       IND        NO  2010-02-07      PASS
# 2100     3743  2010020700       IND        NO  2010-02-07  QB_KNEEL
# 2101     3768  2010020700       IND        NO  2010-02-07      PASS
#
#       replay_or_challenge replay_or_challenge_result
# 0                       0                        NaN
# ...

# %% [markdown]
# Randomly sample 8 entries from the dataframe (1 point)

# %%
df.sample(n=8)
# Out:
#       play_id     game_id home_team away_team   game_date    play_type  \
# 1394     4117  2010011701        SD       NYJ  2010-01-17      NO_PLAY
# 751      1036  2010011601        NO       ARI  2010-01-16         PASS
# 262      2490  2010010900       DAL       PHI  2010-01-09      NO_PLAY
# 1528     2931  2010012400       IND       NYJ  2010-01-24         PUNT
# 1068      519  2010011700       MIN       DAL  2010-01-17   FIELD_GOAL
# 655      3251  2010011000       ARI        GB  2010-01-10  EXTRA_POINT
# 1200     3576  2010011700       MIN       DAL  2010-01-17      NO_PLAY
# 491      3226  2010011001        NE       BAL  2010-01-10      KICKOFF
#
#       replay_or_challenge replay_or_challenge_result
# 1394                    0                        NaN
# 751                     0                        NaN
# 262                     0                        NaN
# 1528                    0                        NaN
# 1068                    0                        NaN
# ...

# %% [markdown]
# Github Link

# %% [markdown]
# https://github.com/amg515/iti221-excercises
